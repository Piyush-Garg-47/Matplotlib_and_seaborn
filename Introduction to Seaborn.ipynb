# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style = "dark")

# %%
x = np.array([1,3,45,6,7,89,0,76,5,32,2,1,13,45,67,78,43])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x ,y=y)
# Out:
# <Axes: >
